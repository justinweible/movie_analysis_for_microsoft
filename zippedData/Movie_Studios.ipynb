# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data_movie_gross = pd.read_csv('zippedData/bom.movie_gross.csv.gz')

# %%
data_title_ratings = pd.read_csv('zippedData/imdb.title.ratings.csv.gz')

# %%
data_title_ratings.head()
# Out:
#        tconst  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559
# 2   tt1042974            6.4        20
# 3   tt1043726            4.2     50352
# 4   tt1060240            6.5        21

# %%
data_title_basics = pd.read_csv('zippedData/imdb.title.basics.csv.gz')

# %%
data_title_basics.head()
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018              NaN          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy

# %%
## Merged imdb.title.basics.csv.gz and imdb.title.ratings.csv.gz on the column 'tconst' with an inner join to eliminate 
## non-matching items.
data_title_overall = pd.merge(data_title_basics, data_title_ratings, on='tconst', how='inner')

# %%
## Renamed 'primary_title' to 'title' in order to smoothly merge this dataframe with bom.movie_gross.csv.gz.
data_title_overall = data_title_overall.rename(columns={'primary_title': 'title'})

# %%
## Merged IMDB and BOM data into one dataframe
movie_titles = pd.merge(data_movie_gross, data_title_overall, on='title', how='inner')

# %%
movie_titles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3027 entries, 0 to 3026
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   title            3027 non-null   object
#  1   studio           3024 non-null   object
#  2   domestic_gross   3005 non-null   float64
#  3   foreign_gross    1832 non-null   object
#  4   year             3027 non-null   int64
#  5   tconst           3027 non-null   object
#  6   original_title   3027 non-null   object
#  7   start_year       3027 non-null   int64
#  8   runtime_minutes  2980 non-null   float64
#  9   genres           3020 non-null   object
#  10  averagerating    3027 non-null   float64
#  11  numvotes         3027 non-null   int64
# dtypes: float64(3), int64(3), object(6)
# memory usage: 307.4+ KB

# %%
movie_titles = movie_titles[['title', 'studio', 'domestic_gross', 'foreign_gross', 'year', 'genres', 'averagerating']]

# %%
movie_titles.dropna(axis=0, how='any', inplace=True)

# %%
movie_titles['foreign_gross'] = movie_titles.foreign_gross.str.split(',').str.join('').astype(float)

# %%
movie_titles['total_gross'] = movie_titles['domestic_gross'] + movie_titles['foreign_gross']

# %%
movie_titles.head()
# Out:
#                         title studio  domestic_gross  foreign_gross  year  \
# 0                 Toy Story 3     BV     415000000.0    652000000.0  2010
# 1                   Inception     WB     292600000.0    535700000.0  2010
# 2         Shrek Forever After   P/DW     238700000.0    513900000.0  2010
# 3  The Twilight Saga: Eclipse   Sum.     300500000.0    398000000.0  2010
# 4                  Iron Man 2   Par.     312400000.0    311500000.0  2010
#
#                        genres  averagerating   total_gross
# 0  Adventure,Animation,Comedy            8.3  1.067000e+09
# 1     Action,Adventure,Sci-Fi            8.8  8.283000e+08
# 2  Adventure,Animation,Comedy            6.3  7.526000e+08
# 3     Adventure,Drama,Fantasy            5.0  6.985000e+08
# 4     Action,Adventure,Sci-Fi            7.0  6.239000e+08

# %%
movie_titles_genres = movie_titles[['title', 'studio', 'genres', 'total_gross', 'year']]

# %%
movie_titles_genres.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1803 entries, 0 to 3001
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        1803 non-null   object
#  1   studio       1803 non-null   object
#  2   genres       1803 non-null   object
#  3   total_gross  1803 non-null   float64
#  4   year         1803 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 84.5+ KB

# %%
movie_titles_genres.tail()
# Out:
#                                         title      studio  \
# 2927               Bilal: A New Breed of Hero          VE
# 2930                          I Still See You         LGF
# 2940                    The Catcher Was a Spy         IFC
# 2959                               Time Freak  Grindstone
# 3001  Antonio Lopez 1970: Sex Fashion & Disco          FM
#
#                           genres  total_gross  year
# 2927  Action,Adventure,Animation    2191000.0  2018
# 2930            Fantasy,Thriller    1501400.0  2018
# 2940         Biography,Drama,War     954000.0  2018
# 2959        Comedy,Drama,Romance     266000.0  2018
# 3001       Biography,Documentary      73200.0  2018

# %%
def count_genre(x):
    data_plot = movie_titles_genres[x].str.cat(sep = ',')
    data = pd.Series(data_plot.split(','))
    info = data.value_counts(ascending=False)
    return info

# %%
total_genre_movies = count_genre('genres')
total_genre_movies.head()
# Out:
# Drama        950
# Comedy       604
# Action       464
# Adventure    368
# Thriller     292
# dtype: int64

# %%
total_genre_movies.plot(kind='barh', figsize=(11,9))
plt.title('Highest Number of Releases by Genre')
plt.xlabel('Number of Releases')
plt.ylabel('Genres')
# Out:
# Text(0, 0.5, 'Genres')

# %%
movie_titles_genres.groupby('year')['total_gross'].mean().plot()
# Out:
# <AxesSubplot:xlabel='year'>

# %%
##Creates an alphabetized list of genres that are separated

unique_genres = movie_titles_genres.genres.unique()
movie_genres_list = []

for x in unique_genres:
    movie_genres_list.extend(x.split(','))

movie_genres = (list(set(movie_genres_list)))
movie_genres = sorted(movie_genres)

# %%
## Changed variable name of list for clarity
genre_list = movie_genres
genre_list
# Out:
# ['Action',
#  'Adventure',
#  'Animation',
#  'Biography',
#  'Comedy',
#  'Crime',
#  'Documentary',
#  'Drama',
#  'Family',
#  'Fantasy',
#  'History',
#  'Horror',
#  'Music',
#  'Musical',
#  'Mystery',
#  'News',
#  'Romance',
#  'Sci-Fi',
#  'Sport',
#  'Thriller',
#  'War',
#  'Western']

# %%
genre_details = list(map(str, (movie_titles_genres['genres'])))

year = np.array(movie_titles_genres['year'])
gross = np.array(movie_titles_genres['total_gross'])

# %%
gross_df = pd.DataFrame(index = genre_list, columns=range(2010, 2019))
gross_df = gross_df.fillna(value = 0.0)
z = 0
for i in genre_details:
    split_genre = list(map(str, i.split(',')))
    gross_df.loc[split_genre, year[z]] = gross_df.loc[split_genre, year[z]] + gross[z]
    z+=1

# %%
gross_df
# Out:
#                      2010          2011          2012          2013  \
# Action       7.955394e+09  1.074833e+10  9.374161e+09  1.062981e+10
# Adventure    9.700117e+09  1.062042e+10  1.091193e+10  1.569493e+10
# Animation    4.163400e+09  4.384255e+09  3.766085e+09  5.189201e+09
# Biography    9.226687e+08  6.077951e+08  5.974323e+08  1.632032e+09
# Comedy       7.801475e+09  7.724342e+09  8.164765e+09  8.178515e+09
# Crime        1.453021e+09  2.567910e+09  1.382405e+09  3.813439e+09
# Documentary  4.202593e+08  1.288452e+09  2.222367e+08  1.249250e+08
# Drama        6.978165e+09  6.691725e+09  5.778802e+09  8.651247e+09
# Family       2.794838e+09  1.503404e+09  1.939200e+09  5.639370e+08
# Fantasy      2.064817e+09  2.740344e+09  3.360126e+09  3.682724e+09
# History      4.111763e+08  3.890270e+08  5.061115e+08  2.925160e+08
# Horror       1.091585e+09  1.091518e+09  1.517030e+09  1.836632e+09
# Music        3.073790e+08  1.272617e+08  3.970260e+08  7.315750e+07
# Musical      9.130930e+07  0.000000e+00  5.940000e+07  0.000000e+00
# Mystery      9.651847e+08  2.016352e+09  9.813936e+08  9.998325e+08
# News         0.000000e+00  6.460000e+07  0.000000e+00  0.000000e+00
# Romance      2.672275e+09  2.534903e+09  1.926890e+09  1.880528e+09
# Sci-Fi       1.742837e+09  3.859956e+09  2.758822e+09  5.898200e+09
# Sport        1.533139e+08  1.540537e+08  1.346006e+08  1.326779e+09
# Thriller     3.215924e+09  3.849052e+09  4.870368e+09  4.742731e+09
# War          1.164050e+08  2.128358e+08  7.644000e+06  7.660000e+07
# Western      2.636211e+08  9.924000e+06  5.335170e+08  2.605000e+08
#
#                      2014          2015          2016          2017  \
# Action       1.359127e+10  1.110402e+10  1.400420e+10  1.509229e+10
# Adventure    1.351319e+10  1.316199e+10  1.596450e+10  1.540108e+10
# Animation    3.467677e+09  3.842207e+09  6.431250e+09  4.410046e+09
# Biography    1.536454e+09  2.596173e+09  1.626297e+09  1.287384e+09
# Comedy       6.687036e+09  9.551216e+09  1.038238e+10  1.019554e+10
# Crime        1.998919e+09  3.140732e+09  1.684501e+09  1.596901e+09
# Documentary  7.110818e+08  1.094473e+09  4.147386e+08  1.275341e+09
# Drama        7.899093e+09  8.202849e+09  7.786165e+09  8.719028e+09
# Family       1.455602e+09  2.090549e+09  1.220500e+09  3.725813e+08
# Fantasy      1.457248e+09  5.721000e+08  3.804750e+09  6.325442e+09
# History      3.148180e+08  1.392587e+09  7.145466e+08  1.084269e+09
# Horror       7.963735e+08  1.517600e+09  1.565176e+09  3.273601e+09
# Music        3.472800e+08  5.548100e+08  5.674500e+08  1.906820e+08
# Musical      2.145250e+08  6.210000e+07  2.840000e+07  4.350000e+08
# Mystery      1.822004e+09  7.750598e+08  1.291996e+09  1.327100e+09
# News         0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# Romance      1.156775e+09  1.318609e+09  1.301097e+09  1.109007e+09
# Sci-Fi       6.343856e+09  4.648613e+09  4.076933e+09  3.420700e+09
# Sport        4.377381e+08  3.217760e+08  1.255000e+08  1.402200e+09
# Thriller     3.547787e+09  4.265310e+09  2.229414e+09  4.038302e+09
# War          2.095491e+08  3.820000e+07  1.714000e+06  1.043150e+08
# Western      8.720000e+07  0.000000e+00  0.000000e+00  1.490000e+07
#
#                      2018
# Action       1.356188e+10
# Adventure    1.435000e+10
# Animation    3.086707e+09
# Biography    1.983847e+09
# Comedy       7.792708e+09
# Crime        1.416246e+09
# Documentary  4.669732e+08
# Drama        6.429736e+09
# Family       1.794427e+09
# Fantasy      3.447159e+09
# History      4.466281e+08
# Horror       2.339301e+09
# Music        9.339000e+08
# Musical      3.950000e+08
# Mystery      1.582600e+09
# News         0.000000e+00
# Romance      1.728504e+09
# Sci-Fi       5.869107e+09
# Sport        2.672900e+08
# Thriller     3.976683e+09
# War          4.754000e+06
# Western      0.000000e+00

# %%
#How the popularity of the genre differ year by year.
sns.set_style("whitegrid")
#make a subplot of size 3,3.
fig, ax = plt.subplots(3,3,figsize = (16,10))

#set the title of the subplot.
fig.suptitle('Genre Popularity Over Year To Year',fontsize = 16)

#plot the 'Drama' genre plot see the popularity difference over year to year.
gross_df.loc['Drama'].plot(label = "Drama",color = '#f67280',ax = ax[0][0],legend=True)

#plot the 'Action' genre plot see the popularity difference over year to year.
gross_df.loc['Action'].plot(label = "Horror",color='#33FFB5',ax = ax[0][1],legend=True)

#plot the 'Comedy' genre plot see the popularity difference over year to year.
gross_df.loc['Comedy'].plot(label = "Comedy",color='#fe5f55',ax = ax[0][2],legend=True)

#accordig to the previous plot the 'Thriller','Science Fiction', 'Romance', 'Music','Adventure' and 'Crime'.
gross_df.loc['Thriller'].plot(label = "Horror",color='#00818a',ax = ax[1][0],legend=True)
gross_df.loc['Sci-Fi'].plot(label = "Sci-Fi",color='#6f6600',ax = ax[1][1],legend=True)
gross_df.loc['Romance'].plot(label = "Romance",color='#1a2c5b',ax = ax[1][2],legend=True)
gross_df.loc['Music'].plot(label = "Music",color='#db3b61',ax = ax[2][0],legend=True)
gross_df.loc['Adventure'].plot(label = "Adventure",color='#08c299',ax = ax[2][1],legend=True)
gross_df.loc['Crime'].plot(label = "Crime",color='c',ax = ax[2][2],legend=True)
# Out:
# <AxesSubplot:>

# %%
gross_df.describe()
# Out:
#                2010          2011          2012          2013          2014  \
# count  2.200000e+01  2.200000e+01  2.200000e+01  2.200000e+01  2.200000e+01
# mean   2.512962e+09  2.872112e+09  2.690452e+09  3.434011e+09  3.072521e+09
# std    2.956662e+09  3.313315e+09  3.224432e+09  4.179135e+09  4.073805e+09
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    3.333283e+08  2.568836e+08  4.242974e+08  2.685040e+08  3.698945e+08
# 50%    1.272303e+09  1.759878e+09  1.449718e+09  1.734332e+09  1.456425e+09
# 75%    3.110653e+09  3.857230e+09  3.664596e+09  5.077584e+09  3.527760e+09
# max    9.700117e+09  1.074833e+10  1.091193e+10  1.569493e+10  1.359127e+10
#
#                2015          2016          2017          2018
# count  2.200000e+01  2.200000e+01  2.200000e+01  2.200000e+01
# mean   3.193226e+09  3.419160e+09  3.685259e+09  3.266975e+09
# std    3.871667e+09  4.646763e+09  4.663350e+09  4.084935e+09
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    5.591325e+08  4.529164e+08  5.973172e+08  4.517144e+08
# 50%    1.455093e+09  1.433137e+09  1.364650e+09  1.761466e+09
# 75%    4.159534e+09  4.008887e+09  4.317110e+09  3.844302e+09
# max    1.316199e+10  1.596450e+10  1.540108e+10  1.435000e+10
